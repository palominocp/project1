# %% [markdown]
# ### Part I: In this part we start with MME analysis

# %%
import pandas as pd
import requests
import json
import gmaps
from sklearn.linear_model import LinearRegression

from sklearn.model_selection import train_test_split 
from sklearn import metrics
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

api_key="your Key"

# %% [markdown]
# MME:
# 1. ATTACHED UE
# 2. BEARERS
# 3. AVECPUUSAGE
# Description: This counter indicates the average CPU utilization in the current interval.
# Unit: %
# Range: 0-100
# 4. PEAKCPUUSAGE
# Description: This counter indicates the peak CPU utilization in the current interval.
# Unit: %
# Range: 0-100
# 5. MEMUSEDSIZE
# Description: This counter identifies the amount of memory (in MB) used in the current
# reporting interval.
# 6. MEMAVAILABLESIZE
# Description: This counter identifies the amount of memory (in MB) available in the current
# reporting interval.
#
# SAEGW:
# 1. Throuhgput
# 2. Maximum number of bearers
# 3. MAXCPUUTILIZATION
# Max CPU utilization per CP-ISA card or per MG-VM in the end of the polling interval. For CMG fast-path cores are excluded from calculations
# 4. MAXMEMORYUTILIZATION
# Max Memory utilization per CP-ISA card or per MG-VM at the end of polling interval.

# %%
#Reading from XLX files to PD. Data Frame
mme = pd.read_excel('Resources/mme.xlsx')
mme_kpi = pd.read_excel('Resources/mme_cpu_mem.xlsx')

# %%
# Show first ten records of MME File
mme.head(10)
# Out:
#      PERIOD_START_TIME LOCATION                       MME  Attached UE  \
# 0  2019-12-02 00:00:00  apodaca  MME-180000-MME01-APODACA        46986
# 1  2019-12-02 00:00:00  apodaca  MME-180000-MME02-APODACA          991
# 2  2019-12-02 00:15:00  apodaca  MME-180000-MME02-APODACA          990
# 3  2019-12-02 00:15:00  apodaca  MME-180000-MME01-APODACA        46953
# 4  2019-12-02 00:30:00  apodaca  MME-180000-MME02-APODACA          991
# 5  2019-12-02 00:30:00  apodaca  MME-180000-MME01-APODACA        46931
# 6  2019-12-02 00:45:00  apodaca  MME-180000-MME01-APODACA        46899
# 7  2019-12-02 00:45:00  apodaca  MME-180000-MME02-APODACA          985
# 8  2019-12-02 01:00:00  apodaca  MME-180000-MME02-APODACA          982
# 9  2019-12-02 01:00:00  apodaca  MME-180000-MME01-APODACA        46871
#
#    EPS Bearers
# 0        48031
# 1         1056
# 2         1058
# 3        48003
# 4         1057
# 5        47967
# 6        47936
# 7         1048
# 8         1044
# 9        47907

# %%
# Show first ten records of MME_KPI File
mme_kpi.head(10)
# Out:
#     LOCATION     DATEDAY    PERIOD_START_TIME                         MME  \
# 0  tultitlan  2019-12-02  2019-12-02 00:00:00  MME-140000-MME01-TULTITLAN
# 1  tultitlan  2019-12-02  2019-12-02 00:15:00  MME-140000-MME01-TULTITLAN
# 2  tultitlan  2019-12-02  2019-12-02 00:30:00  MME-140000-MME01-TULTITLAN
# 3  tultitlan  2019-12-02  2019-12-02 00:45:00  MME-140000-MME01-TULTITLAN
# 4  tultitlan  2019-12-02  2019-12-02 01:00:00  MME-140000-MME01-TULTITLAN
# 5  tultitlan  2019-12-02  2019-12-02 01:15:00  MME-140000-MME01-TULTITLAN
# 6  tultitlan  2019-12-02  2019-12-02 01:30:00  MME-140000-MME01-TULTITLAN
# 7  tultitlan  2019-12-02  2019-12-02 01:45:00  MME-140000-MME01-TULTITLAN
# 8  tultitlan  2019-12-02  2019-12-02 02:00:00  MME-140000-MME01-TULTITLAN
# 9  tultitlan  2019-12-02  2019-12-02 02:15:00  MME-140000-MME01-TULTITLAN
#
#   MANAGEDELEMENT                                         MEASOBJLDN  \
# 0          cmm-1  PoolType=cpps, PoolId=0, PoolMember=0, Machine...
# 1          cmm-1  PoolType=cpps, PoolId=0, PoolMember=0, Machine...
# 2          cmm-1  PoolType=cpps, PoolId=0, PoolMember=0, Machine...
# 3          cmm-1  PoolType=cpps, PoolId=0, PoolMember=0, Machine...
# 4          cmm-1  PoolType=cpps, PoolId=0, PoolMember=0, Machine...
# 5          cmm-1  PoolType=cpps, PoolId=0, PoolMember=0, Machine...
# 6          cmm-1  PoolType=cpps, PoolId=0, PoolMember=0, Machine...
# 7          cmm-1  PoolType=cpps, PoolId=0, PoolMember=0, Machine...
# 8          cmm-1  PoolType=cpps, PoolId=0, PoolMember=0, Machine...
# 9          cmm-1  PoolType=cpps, PoolId=0, PoolMember=0, Machine...
#
#                                   MACHINE  \
# 0  mme-140000-mme01-tultitlan-cpps0.local
# 1  mme-140000-mme01-tultitlan-cpps0.local
# 2  mme-140000-mme01-tultitlan-cpps0.local
# 3  mme-140000-mme01-tultitlan-cpps0.local
# 4  mme-140000-mme01-tultitlan-cpps0.local
# 5  mme-140000-mme01-tultitlan-cpps0.local
# 6  mme-140000-mme01-tultitlan-cpps0.local
# 7  mme-140000-mme01-tultitlan-cpps0.local
# 8  mme-140000-mme01-tultitlan-cpps0.local
# 9  mme-140000-mme01-tultitlan-cpps0.local
#
#                                    UUID  PERIOD_DURATION  AVECPUUSAGE  \
# 0  b726097a-f9f2-4624-bf09-9d1f60177b7c              900            7
# 1  b726097a-f9f2-4624-bf09-9d1f60177b7c              900            7
# 2  b726097a-f9f2-4624-bf09-9d1f60177b7c              900            7
# 3  b726097a-f9f2-4624-bf09-9d1f60177b7c              900            7
# 4  b726097a-f9f2-4624-bf09-9d1f60177b7c              900            7
# 5  b726097a-f9f2-4624-bf09-9d1f60177b7c              900            7
# 6  b726097a-f9f2-4624-bf09-9d1f60177b7c              900            7
# 7  b726097a-f9f2-4624-bf09-9d1f60177b7c              900            7
# 8  b726097a-f9f2-4624-bf09-9d1f60177b7c              900            8
# 9  b726097a-f9f2-4624-bf09-9d1f60177b7c              900            8
#
#    PEAKCPUUSAGE POOLTYPE  POOLID  POOLMEMBER  AVEBASECPUUSAGE  \
# 0            14     cpps     0.0         0.0              7.0
# 1             8     cpps     0.0         0.0              7.0
# 2             9     cpps     0.0         0.0              7.0
# 3             9     cpps     0.0         0.0              7.0
# 4             9     cpps     0.0         0.0              7.0
# 5             9     cpps     0.0         0.0              7.0
# 6             9     cpps     0.0         0.0              7.0
# 7             9     cpps     0.0         0.0              8.0
# 8            16     cpps     0.0         0.0              8.0
# 9            10     cpps     0.0         0.0              8.0
#
#    PEAKBASECPUUSAGE
# 0              13.0
# 1               8.0
# 2               8.0
# 3               8.0
# 4               9.0
# 5               9.0
# 6               9.0
# 7               9.0
# 8              16.0
# 9              10.0

# %%
#Group KPI Files by Location MME and date day
mme_kpi_grp = mme_kpi.groupby(["LOCATION","MME","DATEDAY"])

# %%
#Get Mean of main KPI's
mme_kpi_grp[["AVECPUUSAGE","PEAKCPUUSAGE","PERIOD_DURATION"]].mean()
m_k = mme_kpi_grp[["AVECPUUSAGE","PEAKCPUUSAGE","PERIOD_DURATION"]].mean()
m_k.reset_index(inplace=True)

# %%
#Extract Date and Hour form Period Start Time .
mme["DATEDAY"] = mme["PERIOD_START_TIME"].astype(str).str[:10]
mme["TIME"] = mme["PERIOD_START_TIME"].astype(str).str[11:13]

# %%
#Group by "LOCATION","MME","DATEDAY","TIME"])to get mean of Attacehd UE and EPS Bearers
m_g = mme.groupby(["LOCATION","MME","DATEDAY","TIME"])[["Attached UE","EPS Bearers"]].mean()
m_g.reset_index(inplace=True)
m_g
# Out:
#        LOCATION                         MME     DATEDAY TIME  Attached UE  \
# 0       apodaca    MME-180000-MME01-APODACA  2019-12-02   00     46942.25
# 1       apodaca    MME-180000-MME01-APODACA  2019-12-02   01     46793.50
# 2       apodaca    MME-180000-MME01-APODACA  2019-12-02   02     46586.75
# 3       apodaca    MME-180000-MME01-APODACA  2019-12-02   03     46380.00
# 4       apodaca    MME-180000-MME01-APODACA  2019-12-02   04     46134.50
# ...         ...                         ...         ...  ...          ...
# 1003  tultitlan  MME-140000-MME02-TULTITLAN  2019-12-08   19     41795.75
# 1004  tultitlan  MME-140000-MME02-TULTITLAN  2019-12-08   20     41881.50
# 1005  tultitlan  MME-140000-MME02-TULTITLAN  2019-12-08   21     41943.00
# 1006  tultitlan  MME-140000-MME02-TULTITLAN  2019-12-08   22     41976.50
# 1007  tultitlan  MME-140000-MME02-TULTITLAN  2019-12-08   23     41949.25
#
#       EPS Bearers
# 0        47984.25
# 1        47815.50
# 2        47597.25
# 3        47370.25
# 4        47115.25
# ...           ...
# 1003     43674.75
# 1004     43714.75
# 1005     43772.75
# 1006     43812.00
# 1007     43762.75
#
# [1008 rows x 6 columns]

# %%
mme_df = pd.merge(m_g, m_k,  how='inner', on=["MME","DATEDAY"])
# Merge KPI + Attached US

# %%
del mme_df["LOCATION_y"]
#Delete additional column

# %%
# Rename Columns
mme_df =mme_df.rename(columns={"LOCATION_x":"city"})
mme_df
# Out:
#            city                         MME     DATEDAY TIME  Attached UE  \
# 0       apodaca    MME-180000-MME01-APODACA  2019-12-02   00     46942.25
# 1       apodaca    MME-180000-MME01-APODACA  2019-12-02   01     46793.50
# 2       apodaca    MME-180000-MME01-APODACA  2019-12-02   02     46586.75
# 3       apodaca    MME-180000-MME01-APODACA  2019-12-02   03     46380.00
# 4       apodaca    MME-180000-MME01-APODACA  2019-12-02   04     46134.50
# ...         ...                         ...         ...  ...          ...
# 1003  tultitlan  MME-140000-MME02-TULTITLAN  2019-12-08   19     41795.75
# 1004  tultitlan  MME-140000-MME02-TULTITLAN  2019-12-08   20     41881.50
# 1005  tultitlan  MME-140000-MME02-TULTITLAN  2019-12-08   21     41943.00
# 1006  tultitlan  MME-140000-MME02-TULTITLAN  2019-12-08   22     41976.50
# 1007  tultitlan  MME-140000-MME02-TULTITLAN  2019-12-08   23     41949.25
#
#       EPS Bearers  AVECPUUSAGE  PEAKCPUUSAGE  PERIOD_DURATION
# 0        47984.25     5.547222      9.683333            900.0
# 1        47815.50     5.547222      9.683333            900.0
# 2        47597.25     5.547222      9.683333            900.0
# 3        47370.25     5.547222      9.683333            900.0
# 4        47115.25     5.547222      9.683333            900.0
# ...           ...          ...           ...              ...
# 1003     43674.75     2.854167      7.802696            900.0
# 1004     43714.75     2.854167      7.802696            900.0
# 1005     43772.75     2.854167      7.802696            900.0
# 1006     43812.00     2.854167      7.802696            900.0
# 1007     43762.75     2.854167      7.802696            900.0
#
# [1008 rows x 9 columns]

# %%
#Identify Empty values 
mme_df[pd.isnull(mme_df).any(axis=1)]
#None Found
# Out:
# Empty DataFrame
# Columns: [city, MME, DATEDAY, TIME, Attached UE, EPS Bearers, AVECPUUSAGE, PEAKCPUUSAGE, PERIOD_DURATION]
# Index: []

# %%
#Function to create Box Plots
# Example outlier plot of reaction times
def box_t(data,title,ylabel):
    
    fig1, ax1 = plt.subplots()
    ax1.set_title(f'{title}')
    ax1.set_ylabel(f'{ylabel}')
    ax1.boxplot(data)
    plt.show()

# %%
#Box Plot for KPI Attached UE
#mme_df["Attached UE"]
mmes = mme_df["MME"].unique()
for x in mmes:
    box_t(mme_df[mme_df["MME"] == x]["Attached UE"],f'Box plot for : {x}',"Attached UE")

# %%
sns.set(style="whitegrid")
#Create violin plot to observe the desity and distribution per day

mmes = mme_df["MME"].unique()
for x in mmes:
    plt.figure()
    ax = sns.violinplot(x=mme_df[mme_df["MME"] == x]["DATEDAY"].astype(str).str[8:10], y=mme_df[mme_df["MME"] == x]["Attached UE"])
    plt.title(x)

for x in mmes:
    plt.figure()
    ax = sns.violinplot(x=mme_df[mme_df["MME"] == x]["DATEDAY"].astype(str).str[8:10], y=mme_df[mme_df["MME"] == x]["EPS Bearers"])
    plt.title(x)

# %%
# Function to create scatter plots

def scatter_p(kind,x,y,xlabel,ylabel,title,data):
    scatter = data.plot(kind=kind,x=x,y=y,c='b')
    scatter.set_xlabel(x)
    scatter.set_ylabel(y)
    scatter.set_title(title)

# %%
# Plot the relationship with Attacehd UE and and Average CPU usage for each MME
#Not able to identify corealtion
mmes = mme_df["MME"].unique()
for x in mmes:
    
    scatter_p("scatter","Attached UE","AVECPUUSAGE","Attached UE","AVECPUUSAGE",x,mme_df[mme_df["MME"] == x])

# %%
# Plot the relationship with Attacehd UE and  EPS Bearers usage for each MME
#Linnear corealtion identified
mmes = mme_df["MME"].unique()
for x in mmes:
    
    scatter_p("scatter","Attached UE","EPS Bearers","Attached UE","EPS Bearers",x,mme_df[mme_df["MME"] == x])

# %%
#Confirm relation with a regression nalysis
from scipy.stats import linregress
for mm in mmes:
    x_values = mme_df[mme_df["MME"] == mm]["Attached UE"].values
    y_values = mme_df[mme_df["MME"] == mm]["EPS Bearers"].values
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,(6,10),fontsize=15,color="red")
    plt.xlabel("Attached UE-" + mm)
    plt.ylabel('EPS Bearers' )
    print(f"The r-squared for {mm} is: {rvalue**2}")
    plt.annotate(line_eq,(mme_df[mme_df["MME"] == mm]["EPS Bearers"].min(),mme_df[mme_df["MME"] == mm]["Attached UE"].min()),fontsize=15,color="red")
    plt.show()
# Out:
# The r-squared for MME-180000-MME01-APODACA is: 0.9862639750384431
# The r-squared for MME-180000-MME02-APODACA is: 0.9999932268958474
# The r-squared for MME-250000-MME01-HERMOSILLO is: 0.9575545750716976
# The r-squared for MME-300000-MME01-MERIDA is: 0.9998407613029967
# The r-squared for MME-140000-MME01-TULTITLAN is: 0.9945253478273746
# The r-squared for MME-140000-MME02-TULTITLAN is: 0.9999911278807705

# %%
# Create linear regression model and compare train vs testing

mmes = mme_df["MME"].unique()
for mm in mmes:
    regressor = LinearRegression()
    X_train, X_test, y_train, y_test = train_test_split(mme_df[mme_df["MME"] == mm]["Attached UE"].values.reshape(-1,1), mme_df[mme_df["MME"] == mm]["EPS Bearers"].values.reshape(-1,1), test_size=0.2, random_state=0)
    
    regressor.fit(X_train, y_train)
    
    y_predict =regressor.predict(X_test)

    
    plt.scatter(X_test, y_test,  color='gray')
    plt.xlabel("Attached UE" + mm)
    plt.ylabel("EPS Bearers")
    
    plt.plot(X_test, y_predict, color='red', linewidth=2)
    
    plt.show()



#bar = plt.subplot()

# %%
#Prepare data to get Lat and Lng from Google
cities = mme_df["city"].unique()
mmes = mme_df["MME"].unique()
cities

lat=[]
lng=[]
maxcap = dict()
#Get MAx values to compare capacity - Data provided by expert
maxcap = {'MME-180000-MME01-APODACA':1485457, 'MME-180000-MME02-APODACA':1485457,
       'MME-250000-MME01-HERMOSILLO':200464, 'MME-300000-MME01-MERIDA':135838,
       'MME-140000-MME01-TULTITLAN':2380000, 'MME-140000-MME02-TULTITLAN':2380000}

#Get Lat and lng for all cities , only the required calls to Google api
for city in cities:
    url=f"https://maps.googleapis.com/maps/api/geocode/json?address={city}&key={api_key}"
    response=requests.get(url).json()
    lat.append(response["results"][0]["geometry"]["location"]["lat"])
    lng.append(response["results"][0]["geometry"]["location"]["lng"])
    mme_df.loc[(mme_df["city"] == city),'lat']=response["results"][0]["geometry"]["location"]["lat"]
    mme_df.loc[(mme_df["city"] == city),'lng']=response["results"][0]["geometry"]["location"]["lng"]


#Calculate Cpapcity percentage     
for mm in mmes:
    
    mme_df.loc[(mme_df["MME"] == mm),'maxcap']=maxcap[mm]
    #mme_df.loc[(mme_df["MME"] == mm),'capperc']=maxcap[mm]

mme_df["capperc"] = (mme_df["Attached UE"] / mme_df["maxcap"] )
mme_df.style.format({'capperc': "{:.2%}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_cfd529ea_d999_11ea_9563_f45c89afcb9d" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >city</th>        <th class="col_heading level0 col1" >MME</th>        <th class="col_heading level0 col2" >DATEDAY</th>        <th class="col_heading level0 col3" >TIME</th>        <th class="col_heading level0 col4" >Attached UE</th>        <th class="col_heading level0 col5" >EPS Bearers</th>        <th class="col_heading level0 col6" >AVECPUUSAGE</th>        <th class="col_heading level0 col7" >PEAKCPUUSAGE</th>        <th class="col_heading level0 col8" >PERIOD_DURATION</th>        <th class="col_heading level0 col9" >lat</th>        <th class="col_heading level0 col10" >lng</th>        <th class="col_heading level0 col11" >maxcap</th>        <th class="col_heading level0 col12" >capperc</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_cfd529ea_d999_11ea_9563_f45c89afcb9dlevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_cfd529ea_d999_11ea_9563_f45c89afcb9drow0_col0" class="data row0 col0" >apodaca</td>
#                         <td id="T_cfd529ea_d999_11ea_9563_f45c89afcb9drow0_col1" class="data row0 col1" >MME-180000-MME01-APODACA</td>
#                         <td id="T_cfd529ea_d999_11ea_9563_f45c89afcb9drow0_col2" class="data row0 col2" >2019-12-02</td>
#                         <td id="T_cfd529ea_d999_11ea_9563_f45c89afcb9drow0_col3" class="data row0 col3" >00</td>
#                         <td id="T_cfd529ea_d999_11ea_9563_f45c89afcb9drow0_col4" class="data row0 col4" >46942.250000</td>
#                         <td id="T_cfd529ea_d999_11ea_9563_f45c89afcb9drow0_col5" class="data row0 col5" >47984.250000</td>
#                         <td id="T_cfd529ea_d999_11ea_9563_f45c89afcb9drow0_col6" class="data row0 col6" >5.547222</td>
#                         <td id="T_cfd529ea_d999_11ea_9563_f45c89afcb9drow0_col7" class="data row0 col7" >9.683333</td>
#                         <td id="T_cfd529ea_d999_11ea_9563_f45c89afcb9drow0_col8" class="data row0 col8" >900.000000</td>
#                         <td id="T_cfd529ea_d999_11ea_9563_f45c89afcb9drow0_col9" class="data row0 col9" >25.776468</td>
#                         <td id="T_cfd529ea_d999_11ea_9563_f45c89afcb9drow0_col10" class="data row0 col10" >-100.185874</td>
#                         <td id="T_cfd529ea_d999_11ea_9563_f45c89afcb9drow0_col11" class="data row0 col11" >1485457.000000</td>
#                         <td id="T_cfd529ea_d999_11ea_9563_f45c89afcb9drow0_col12" class="data row0 col12" >3.16%</td>
#             </tr>
#             <tr>
#                         <th id="T_cfd529ea_d999_11ea_9563_f45c89afcb9dlevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_cfd529ea_d999_11ea_9563_f45c89afcb9drow1_col0" class="data row1 col0" >apodaca</td>
#                         <td id="T_cfd529ea_d999_11ea_9563_f45c89afcb9drow1_col1" class="data row1 col1" >MME-180000-MME01-APODACA</td>
#                         <td id="T_cfd529ea_d999_11ea_9563_f45c89afcb9drow1_col2" class="data row1 col2" >2019-12-02</td>
#                         <td id="T_cfd529ea_d999_11ea_9563_f45c89afcb9drow1_col3" class="data row1 col3" >01</td>
#                         <td id="T_cfd529ea_d999_11ea_9563_f45c89afcb9drow1_col4" class="data row1 col4" >46793.500000</td>
#                         <td id="T_cfd529ea_d999_11ea_9563_f45c89afcb9drow1_col5" class="data row1 col5" >47815.500000</td>
#                         <td id="T_cfd529ea_d999_11ea_9563_f45c89afcb9drow1_col6" class="data row1 col6" >5.547222</td>
#                         <td id="T_cfd529ea_d999_11ea_9563_f45c89afcb9drow1_col7" class="data row1 col7" >9.683333</td>
#                         <td id="T_cfd529ea_d999_11ea_9563_f45c89afcb9drow1_col8" class="data row1 col8" >900.000000</td>
#                         <td id="T_cfd529ea_d999_11ea_9563_f45c89afcb9drow1_col9" class="data row1 col9" >25.776468</td>
#                         <td id="T_cfd529ea_d999_11ea_9563_f45c89afcb9drow1_col10" class="data row1 col10" >-100.185874</td>
#                         <td id="T_cfd529ea_d999_11ea_9563_f45c89afcb9drow1_col11" class="data row1 col11" >1485457.000000</td>
#                         <td id="T_cfd529ea_d999_11ea_9563_f45c89afcb9drow1_col12" class="data row1 col12" >3.15%</td>
#             </tr>
#             <tr>
#                         <th id="T_cfd529ea_d999_11ea_9563_f45c89afcb9dlevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_cfd529ea_d999_11ea_9563_f45c89afcb9drow2_col0" class="data row2 col0" >apodaca</td>
#                         <td id="T_cfd529ea_d999_11ea_9563_f45c89afcb9drow2_col1" class="data row2 col1" >MME-180000-MME01-APODACA</td>
#                         <td id="T_cfd529ea_d999_11ea_9563_f45c89afcb9drow2_col2" class="data row2 col2" >2019-12-02</td>
#                         <td id="T_cfd529ea_d999_11ea_9563_f45c89afcb9drow2_col3" class="data row2 col3" >02</td>
#                         <td id="T_cfd529ea_d999_11ea_9563_f45c89afcb9drow2_col4" class="data row2 col4" >46586.750000</td>
#                         <td id="T_cfd529ea_d999_11ea_9563_f45c89afcb9drow2_col5" class="data row2 col5" >47597.250000</td>
#                         <td id="T_cfd529ea_d999_11ea_9563_f45c89afcb9drow2_col6" class="data row2 col6" >5.547222</td>
#                         <td id="T_cfd529ea_d999_11ea_9563_f45c89afcb9drow2_col7" class="data row2 col7" >9.683333</td>
#                         <td id="T_cfd529ea_d999_11ea_9563_f45c89afcb9drow2_col8" class="data row2 col8" >900.000000</td>
#                         <td id="T_cfd529ea_d999_11ea_9563_f45c89afcb9drow2_col9" class="data row2 col9" >25.776468</td>
#                         <td id="T_cfd529ea_d999_11ea_9563_f45c89afcb9drow2_col10" class="data row2 col10" >-100.185874</td>
#                         <td id="T_cfd529ea_d999_11ea_9563_f45c89afcb9drow2_col11" class="data row2 col11" >1485457.000000</td>
#                         <td id="T_cfd529ea_d999_11ea_9563_f45c89afcb9drow2_col12" class="data row2 col12" >3.14%</td>
#             </tr>
#             <tr>
#                         <th id="T_cfd529ea_d999_11ea_9563_f45c89afcb9dlevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_cfd529ea_d999_11ea_9563_f45c89afcb9drow3_col0" class="data row3 col0" >apodaca</td>
#                         <td id="T_cfd529ea_d999_11ea_9563_f45c89afcb9drow3_col1" class="data row3 col1" >MME-180000-MME01-APODACA</td>
#                         <td id="T_cfd529ea_d999_11ea_9563_f45c89afcb9drow3_col2" class="data row3 col2" >2019-12-02</td>
#                         <td id="T_cfd529ea_d999_11ea_9563_f45c89afcb9drow3_col3" class="data row3 col3" >03</td>
#                         <td id="T_cfd529ea_d999_11ea_9563_f45c89afcb9drow3_col4" class="data row3 col4" >46380.000000</td>
#                         <td id="T_cfd529ea_d999_11ea_9563_f45c89afcb9drow3_col5" class="data row3 col5" >47370.250000</td>
#                         <td id="T_cfd529ea_d999_11ea_9563_f45c89afcb9drow3_col6" class="data row3 col6" >5.547222</td>
#                         <td id="T_cfd529ea_d999_11ea_9563_f45c89afcb9drow3_col7" class="data row3 col7" >9.683333</td>
#                         <td id="T_cfd529ea_d999_11ea_9563_f45c89afcb9drow3_col8" class="data row3 col8" >900.000000</td>
#                         <td id="T_cfd529ea_d999_11ea_9563_f45c89afcb9drow3_col9" class="data row3 col9" >25.776468</td>
#                         <td id="T_cfd529ea_d999_11ea_9563_f45c89afcb9drow3_col10" class="data row3 col10" >-100.185874</td>
#                         <td id="T_cfd529ea_d999_11ea_9563_f45c89afcb9drow3_col11" class="data row3 col11" >1485457.000000</td>
#                         <td id="T_cfd529ea_d999_11ea_9563_f45c89afcb9drow3_col12" class="data row3 col12" >3.12%</td>
#             </tr>
#             <tr>
#                         <th id="T_cfd529ea_d999_11ea_9563_f45c89afcb9dlevel0_row4" class="row_heading level0

# %%
cities_data = pd.DataFrame(zip(cities,lat,lng),columns=['city','lat','lng'])
#cities_data
# Out:
# array(['MME-180000-MME01-APODACA', 'MME-180000-MME02-APODACA',
#        'MME-250000-MME01-HERMOSILLO', 'MME-300000-MME01-MERIDA',
#        'MME-140000-MME01-TULTITLAN', 'MME-140000-MME02-TULTITLAN'],
#       dtype=object)

# %%
m=mme_df.groupby(["MME","city","lat","lng"]).agg(["mean","sum","max","min"])
cities_data = m.reset_index()
cities_data
cities_data["capperc"]

##MME , Columnas por dia, Valor Maximo y pocentaje utilizado  (Max/Attached) Color
# Out:
#        mean        sum       max       min
# 0  0.084087  14.126689  0.092699  0.074287
# 1  0.008373   1.406669  0.019822  0.001513
# 2  0.030954   5.200287  0.034243  0.027218
# 3  0.002875   0.482927  0.006184  0.000644
# 4  0.004716   0.792231  0.005673  0.003385
# 5  0.014201   2.385706  0.017490  0.010801

# %%
# Heat map attached cities
fig = gmaps.figure(center=(20.0, -100.0), zoom_level=2.8)


heat_layer = gmaps.heatmap_layer(locations=cities_data[["lat","lng"]].astype(float), weights=cities_data["Attached UE"]["mean"], 
                             dissipating=False, max_intensity=100
                             ,point_radius = 1)

# Add marker layer ontop of heat map


sym_layer = gmaps.symbol_layer(
    locations=cities_data[["lat","lng"]].astype(float), fill_color='rgba(0, 150, 0, 0.4)',
    stroke_color='rgba(0, 0, 150, 0.4)', scale=5,
    info_box_content=[f"City: {row['city']},  Attached UE :{row[['Attached UE','EPS Bearers']]} " for index,row in cities_data.iterrows()]
)
fig.add_layer(heat_layer)
fig.add_layer(sym_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Function to create bar plots

def bar_p(kind,x,y,xlabel,ylabel,title,data):
    scatter = data.plot(kind=kind,x=x,y=y)
    scatter.set_xlabel(x)
    scatter.set_ylabel(y)
    scatter.set_title(title)

# %%
#Identify the max number of attached users per day
m=mme_df.groupby(["MME","city","DATEDAY"]).max()
m.reset_index(inplace=True)
mmes = m["MME"].unique()
for x in mmes:
    
    bar_p("bar","DATEDAY","Attached UE","Date","Attached UE",x,m[m["MME"] == x])

# %%
day=mme_df.groupby(["MME","DATEDAY"])["Attached UE"].max().reset_index()

# %%
#Identify the max number of attached users per hour
m=mme_df.groupby(["MME","city","TIME"]).max()
m.reset_index(inplace=True)
mmes = m["MME"].unique()
for x in mmes:
    
    bar_p("bar","TIME","Attached UE","Date","Attached UE",x,m[m["MME"] == x])

# %%
#Identify the capacity % number per day
m=mme_df.groupby(["MME","city","DATEDAY"]).max()
m.reset_index(inplace=True)
mmes = m["MME"].unique()
for x in mmes:
    
    bar_p("bar","DATEDAY","capperc","Date","% Utilizacion",x,m[m["MME"] == x])

# %%
#Get mean of capacity percentage by MME
s=m.groupby("MME")["capperc"].max().reset_index()
s["capperc"]=s["capperc"]*100
s.style.format({'capperc': "{:.2%}"},)
s.plot(kind="bar",x="MME")

# %% [markdown]
# ### Part II: Here we start with SAEGW analysis:

# %%
# Set excel paths
saegw = "Resources/saegw.xlsx"
saegw_bearers = "Resources/saegw_bearers.xlsx"

groupby_saegw = pd.read_excel(saegw).groupby(['dateday','SAEGW'])
saegw_df = groupby_saegw.max()
saegw_bearers_df = pd.read_excel(saegw_bearers)

# merge and clean
merge_saegw = pd.merge(saegw_df,saegw_bearers_df, on=["dateday","SAEGW"])
merge_saegw_clean = merge_saegw[['dateday', 'SAEGW', 'LOCATION_x', 'Throuhgput', 'Maximum number of bearers']]

# %%
# Plot all SAEGW
plot_all = merge_saegw_clean.groupby(['SAEGW']).max()
plot_all.reset_index(inplace=True)
plot_all.plot.bar(x=0,y=3,title= "All Maximum Throughput")
plt.savefig('All Maximum Throughput')

# %%
# Create new tables by location
tultitlan = merge_saegw_clean[merge_saegw_clean.LOCATION_x == 'tultitlan']
apodaca = merge_saegw_clean[merge_saegw_clean.LOCATION_x == 'apodaca']
hermosillo = merge_saegw_clean[merge_saegw_clean.LOCATION_x == 'hermosillo']
merida = merge_saegw_clean[merge_saegw_clean.LOCATION_x == 'merida']

# %%
# Create plots based on tultitlan 1
tult_max_saegw = tultitlan.groupby(['SAEGW']).max()
tult_max_saegw.reset_index(inplace=True)
tult_max_saegw.head(2).plot.bar(x=0,y=3,label="Max Throughput",title='Tultitlan Maximum Throughput 1').set_ylim(0,150000)
plt.hlines(32000,-1,2,color='y')
plt.hlines(40000,-1,2,color='r')
plt.savefig('Tultitlan Maximum Throughput 1')

# %%
# Create plots based on tultitlan 2
tult_max_saegw = tultitlan.groupby(['SAEGW']).max()
tult_max_saegw.reset_index(inplace=True)
tult_max_saegw.tail(2).plot.bar(x=0,y=3,label="Max Throughput",title='Tultitlan Maximum Throughput 2').set_ylim(0,150000)
plt.hlines(115200,-1,2,color='y')
plt.hlines(144000,-1,2,color='r')
plt.savefig('Tultitlan Maximum Throughput 2')

# %%
# Create plots based on apodaca 1
apo_max_saegw = apodaca.groupby(['SAEGW']).max()
apo_max_saegw.reset_index(inplace=True)
apo_max_saegw.head(2).plot.bar(x=0,y=3,label='Max Throughput',title="Apodaca Maximum Throughput 1").set_ylim(0,150000)
plt.hlines(32000,-1,2,color='y')
plt.hlines(40000,-1,2,color='r')
plt.savefig('Apodaca Maximum Throughput 1')

# %%
# Create plots based on apodaca 2
apo_max_saegw = apodaca.groupby(['SAEGW']).max()
apo_max_saegw.reset_index(inplace=True)
apo_max_saegw.tail(1).plot.bar(x=0,y=3,label='Max Throughput',title="Apodaca Maximum Throughput 2").set_ylim(0,150000)
plt.hlines(115200,-1,1,color='y')
plt.hlines(144000,-1,1,color='r')
plt.savefig('Apodaca Maximum Throughput 2')

# %%
# Create plots based on hermosillo
her_max_saegw = hermosillo.groupby(['SAEGW']).max()
her_max_saegw.reset_index(inplace=True)
her_max_saegw.plot.bar(x=0,y=3,label='Max Throughput',title="Hermosillo Maximum Throughput")
plt.hlines(10000,-1,4,color='r')
plt.hlines(8000,-1,4,color='y')
plt.savefig("Hermosillo Maximum Throughput")

# %%
# Create plots based on merida
mer_max_saegw = merida.groupby(['SAEGW']).max()
mer_max_saegw.reset_index(inplace=True)
mer_max_saegw.plot.bar(x=0,y=3,label='Max Throughput',title="Merida Maximum Throughput")
plt.hlines(10000,-1,4,color='r')
plt.hlines(8000,-1,4,color='y')
plt.savefig("Merdia Maximum Throughput")

# %%
# Start day of the week analysis
week_all = merge_saegw_clean.groupby(['dateday']).mean().reset_index()
week_all.plot.bar(x=0,y=1,legend=False,title='Average throughput by day of the week')
plt.savefig('Week_all')

# %%
# day of the week analysis Tultitlan
tult_week = tultitlan.groupby('dateday').mean().reset_index()
tult_week.plot.bar(x=0,y=1,legend=False,title='Tultitlan use by weekday')
plt.savefig('Tultitlan_week')

# %%
# day of the week analysis Apodaca
apo_week = apodaca.groupby('dateday').mean().reset_index()
apo_week.plot.bar(x=0,y=1,legend=False,title='Apodaca use by weekday')
plt.savefig('Apodaca_week')

# %%
# day of the week analysis Hermosillo
her_week = hermosillo.groupby('dateday').mean().reset_index()
her_week.plot.bar(x=0,y=1,legend=False,title='Hermosillo use by weekday')
plt.savefig('Hermosillo_week')

# %%
# day of the week analysis Merida
mer_week = merida.groupby('dateday').mean().reset_index()
mer_week.plot.bar(x=0,y=1,legend=False,title='Merida use by weekday')
plt.savefig('Merida_week')
